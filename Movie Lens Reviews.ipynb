# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('RankingData/TheMoviesDataset/movies_metadata.csv')
data.sort_values('vote_average')
# Out:
# /Users/bear-mbp/anaconda/envs/py27/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                                    adult  \
# 45465                                              False
# 24507                                              False
# 24506                                              False
# 24498                                              False
# 24497                                              False
# 24463                                              False
# 24441                                              False
# 24436                                              False
# 24420                                              False
# 24545                                              False
# 24416                                              False
# ...

# %%
amzn = pd.read_csv('/private/tmp/amazon_reviews_us_Video_DVD_v1_00.tsv', 
                   delimiter='\t',
                   error_bad_lines=False)
amzn
# Out:
# Skipping line 1890: expected 15 fields, saw 22
# Skipping line 6666: expected 15 fields, saw 22
#
# Skipping line 111408: expected 15 fields, saw 22
#
# Skipping line 170181: expected 15 fields, saw 22
# Skipping line 170231: expected 15 fields, saw 22
#
# Skipping line 256196: expected 15 fields, saw 22
#
# Skipping line 295037: expected 15 fields, saw 22
#
# Skipping line 548974: expected 15 fields, saw 22
# Skipping line 551265: expected 15 fields, saw 22
# Skipping line 551973: expected 15 fields, saw 22
#
# Skipping line 619923: expected 15 fields, saw 22
#
# Skipping line 763610: expected 15 fields, saw 22
#
# Skipping line 798928: expected 15 fields, saw 22
#
# Skipping line 859446: expected 15 fields, saw 22
#
# Skipping line 972328: expected 15 fields, saw 22
#
# Skipping line 988275: expected 15 fields, saw 22
#
# Skipping line 1133741: expected 15 fields, saw 22
#
# Skipping line 1278960: expected 15 fields, saw 22
#
# Skipping line 1317934: expected 15 fields, saw 22
#
# ...

# %%
amzn_product_titles = amzn.product_title.unique()
matching_titles = data[data.title.isin(amzn_product_titles)]

# %%
matching_titles.vote_average.describe()
# Out:
# count    23628.000000
# mean         5.748984
# std          1.632130
# min          0.000000
# 25%          5.200000
# 50%          6.000000
# 75%          6.700000
# max         10.000000
# Name: vote_average, dtype: float64

# %%
plt.hist(matching_titles.vote_average)
plt.show()

# %%
matching_titles.vote_count.describe()
# Out:
# count    23628.000000
# mean       160.982859
# std        601.219654
# min          0.000000
# 25%          5.000000
# 50%         16.000000
# 75%         62.000000
# max      14075.000000
# Name: vote_count, dtype: float64

# %%
matching_titles['percentile_rank'] = matching_titles.vote_average.rank(pct=True)
matching_titles
# Out:
# /Users/bear-mbp/anaconda/envs/py27/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 5      False                                                NaN  60000000
# 6      False                                                NaN  58000000
# ...
