# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
games = pd.read_csv('RankingData/VideoGameSalesWithRatings/Video_Games_Sales_as_at_22_Dec_2016.csv')
games.sort_values('Critic_Score')
# Out:
#                                                     Name Platform  \
# 13690                                       Ride to Hell      PS3
# 10663                Leisure Suit Larry: Box Office Bust      PS3
# 12823                                       Ride to Hell     X360
# 10016                                           Rugby 15      PS4
# 15345                                      Balls of Fury      Wii
# 9106                                       Chicken Shoot       DS
# 12132                                          Anubis II      Wii
# 7219                             Nickelodeon Party Blast       XB
# 1050                                     Deal or No Deal       DS
# 11443                                     Ninjabread Man      Wii
# 11223                                           Rugby 15     XOne
# 9991                          Self-Defense Training Camp     X360
# 12047                            Drake of the 99 Dragons       XB
# ...

# %%
games.columns
# Out:
# Index([u'Name', u'Platform', u'Year_of_Release', u'Genre', u'Publisher',
#        u'NA_Sales', u'EU_Sales', u'JP_Sales', u'Other_Sales', u'Global_Sales',
#        u'Critic_Score', u'Critic_Count', u'User_Score', u'User_Count',
#        u'Developer', u'Rating'],
#       dtype='object')

# %%
amzn = pd.read_csv('/private/tmp/amazon_reviews_us_Video_Games_v1_00.tsv', 
                   delimiter='\t',
                   error_bad_lines=False)
amzn
# Out:
# Skipping line 20630: expected 15 fields, saw 22
# Skipping line 28172: expected 15 fields, saw 22
# Skipping line 54791: expected 15 fields, saw 22
#
# Skipping line 75419: expected 15 fields, saw 22
# Skipping line 104832: expected 15 fields, saw 22
#
# Skipping line 138464: expected 15 fields, saw 22
# Skipping line 194849: expected 15 fields, saw 22
#
# Skipping line 201568: expected 15 fields, saw 22
# Skipping line 242567: expected 15 fields, saw 22
#
# Skipping line 493585: expected 15 fields, saw 22
# Skipping line 502478: expected 15 fields, saw 22
#
# Skipping line 660750: expected 15 fields, saw 22
#         marketplace  customer_id       review_id  product_id  product_parent  \
# 0                US     12039526   RTIS3L2M1F5SM  B001CXYMFS       737716809
# 1                US      9636577   R1ZV7R40OLHKD  B00M920ND6       569686175
# 2                US      2331478  R3BH071QLH8QMC  B0029CSOD2        98937668
# ...

# %%
amzn_product_titles = amzn.product_title.unique()
matching_titles = games[games.Name.isin(amzn_product_titles)]
matching_titles = matching_titles[~pd.isnull(matching_titles['Critic_Score'])]

# %%
plt.hist(matching_titles.Critic_Score)
plt.show()

# %%
plt.hist( matching_titles[~pd.isnull(matching_titles['User_Score']) & (matching_titles['User_Score'] != 'tbd')].User_Score.astype(float) )
plt.show()

# %%
matching_titles.User_Count.describe()
# Out:
# count     3655.000000
# mean       210.738988
# std        670.200651
# min          4.000000
# 25%         11.000000
# 50%         29.000000
# 75%        111.000000
# max      10665.000000
# Name: User_Count, dtype: float64

# %%
matching_titles['percentile_rank'] = matching_titles.Critic_Score.rank(pct=True)
matching_titles
# Out:
#                                              Name Platform  Year_of_Release  \
# 0                                      Wii Sports      Wii           2006.0
# 2                                  Mario Kart Wii      Wii           2008.0
# 3                               Wii Sports Resort      Wii           2009.0
# 6                           New Super Mario Bros.       DS           2006.0
# 7                                        Wii Play      Wii           2006.0
# 8                       New Super Mario Bros. Wii      Wii           2009.0
# 11                                  Mario Kart DS       DS           2005.0
# 13                                        Wii Fit      Wii           2007.0
# 15                                   Wii Fit Plus      Wii           2009.0
# 16                             Grand Theft Auto V      PS3           2013.0
# 17                  Grand Theft Auto: San Andreas      PS2           2004.0
# ...
