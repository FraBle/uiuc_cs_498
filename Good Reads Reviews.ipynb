# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
books = pd.read_csv('RankingData/GoodBooks10k/books.csv')
books.sort_values('average_rating')
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 1792     1793             105578        105578    101770           25
# 3549     3550             783291        783291   1584738           63
# 8006     8007            8664368       8664368  13535892           45
# 9020     9021              24929         24929   1130986           18
# 4008     4009               6613          6613   2548756           57
# 8165     8166           23503361      23503361  43085307           19
# 8873     8874            6855294       6855294   7068970           37
# 4282     4283           16130307      16130307  20391423           59
# 4613     4614               3648          3648   3255539           45
# 8959     8960           12878667      12878667  17997709           36
# 4281     4282            4601396       4601396   4651129           50
# 1408     1409            3320520       3320520   3358314           18
# ...

# %%
books.columns
# Out:
# Index([u'book_id', u'goodreads_book_id', u'best_book_id', u'work_id',
#        u'books_count', u'isbn', u'isbn13', u'authors',
#        u'original_publication_year', u'original_title', u'title',
#        u'language_code', u'average_rating', u'ratings_count',
#        u'work_ratings_count', u'work_text_reviews_count', u'ratings_1',
#        u'ratings_2', u'ratings_3', u'ratings_4', u'ratings_5', u'image_url',
#        u'small_image_url'],
#       dtype='object')

# %%
amzn = pd.read_csv('/private/tmp/amazon_reviews_us_Books_v1_01.tsv', 
                   delimiter='\t',
                   error_bad_lines=False)
amzn
# Out:
# Skipping line 2750083: expected 15 fields, saw 22
#
# /Users/bear-mbp/anaconda/envs/py27/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         marketplace  customer_id       review_id  product_id  product_parent  \
# 0                US     22480053  R28HBXXO1UEVJT  0843952016        34858117
# 1                US     44244451   RZKRFS2UUMFFU  031088926X       676347131
# 2                US     20357422  R2WAU9MD9K6JQA  0615268102       763837025
# 3                US     13235208  R36SCTKYTVPZPC  1900869225       785539232
# 4                US     26301786  R10BM6JUOJX27Q  1565129938        64646125
# 5                US     27780192   RCLZ5OKZNUSY4  146854456X       270349766
# 6                US     13041546  R1S65DJYEI89G4  1118094514       752141158
# ...

# %%
amzn['star_rating'] = pd.to_numeric(amzn.star_rating, errors='coerce')
amzn.dropna(subset=['star_rating'], inplace=True)

# %%
amzn_product_titles = amzn.product_title.unique()
matching_titles = books[books.title.isin(amzn_product_titles)]

# %%
plt.hist(matching_titles.average_rating)
plt.show()

# %%
matching_titles.ratings_count.describe()
# Out:
# count    3.926000e+03
# mean     6.247076e+04
# std      1.639113e+05
# min      4.713000e+03
# 25%      1.307975e+04
# 50%      2.076950e+04
# 75%      4.556375e+04
# max      3.198671e+06
# Name: ratings_count, dtype: float64

# %%
matching_titles['percentile_rank'] = matching_titles.average_rating.rank(pct=True)
matching_titles
# Out:
# /Users/bear-mbp/anaconda/envs/py27/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 3           4               2657          2657   3275794          487
# 4           5               4671          4671    245494         1356
# 5           6           11870085      11870085  16827462          226
# 6           7               5907          5907   1540236          969
# 7           8               5107          5107   3036731          360
# 9          10               1885          1885   3060926         3455
# 10         11              77203         77203   3295919          283
# ...

# %%
matching_titles.columns
# Out:
# Index([u'book_id', u'goodreads_book_id', u'best_book_id', u'work_id',
#        u'books_count', u'isbn', u'isbn13', u'authors',
#        u'original_publication_year', u'original_title', u'title',
#        u'language_code', u'average_rating', u'ratings_count',
#        u'work_ratings_count', u'work_text_reviews_count', u'ratings_1',
#        u'ratings_2', u'ratings_3', u'ratings_4', u'ratings_5', u'image_url',
#        u'small_image_url', u'percentile_rank'],
#       dtype='object')

# %%
amzn_df = amzn[amzn.product_title.isin(matching_titles.title)].groupby('product_title').agg(['mean', 'count'])

# %%
def remove_column_hierarchy(tier_df):
    tier_df = tier_df.copy()
    tier_df.reset_index(inplace=True)
    tier_df.columns = ["_".join(c).strip('_') for c in tier_df.columns]
    return tier_df

def add_target(tier_df, target_value, tier):
    tier_df = tier_df.copy()
    tier_df['target'] = target_value
    tier_df['tier'] = tier
    return tier_df

pd.merge(remove_column_hierarchy(amzn_df), matching_titles, left_on=['product_title'], right_on=['title']).sort_values('percentile_rank')
# Out:
#                                           product_title  customer_id_mean  \
# 2384                                    The Almost Moon          35445633
# 2721                               The Finkler Question          38084147
# 935                                        Four Blondes          27902425
# 1504                                               Lost          34968285
# 2336                                           Tell-All          35690762
# 2683                             The Emperor's Children          38428545
# 3259                                      The Red House          37305338
# 1971                                              Pygmy          31761745
# 2359                          The 3 Mistakes of My Life          29798677
# 2759                                      The Gathering          37553212
# 2914                          The Jane Austen Book Club          37836264
# 138                               A Wedding in December          36078310
# ...
